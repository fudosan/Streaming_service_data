# %% [markdown]
# Importing standard packages

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Setting display option

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# Reading data

# %%
incidents = pd.read_csv('incidents.csv')

# %%
incidents
# Out:
#                           _id  account_id  account_profile_id  accuracy_radius                              action  age  app_ver      city                                         controller                 country country_code                   created              device_model device_type get_params     ip_address                       isp  loc.lat  loc.long                                            message post_params sex  subscription_id  tenant_id        time_zone    user_agent
# 0    5d95db345b96e82a26502a3e       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T11:27:48.902Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: None of the available extractor...        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 1    5d95db355b96e82a26502a40       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T11:27:49.611Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: None of the available extractor...        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 2    5d95db365b96e82a26502a42       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T11:27:50.285Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: None of the available extractor...        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 3    5d95db365b96e82a26502a43       72029              318008             1000                           onError()   32      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T11:27:50.937Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                 ANDROID-STB :: Wecast Player error        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 4    5d95db375b96e82a26502a45       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T11:27:51.031Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: None of the available extractor...        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 5    5d95db685b96e82a26502a47       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T11:28:40.500Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: None of the available extractor...        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 6    5d95db685b96e82a26502a49       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T11:28:40.956Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: None of the available extractor...        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 7    5d95db695b96e82a26502a4b       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T11:28:41.384Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: None of the available extractor...        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 8    5d95db695b96e82a26502a4d       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T11:28:41.816Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: None of the available extractor...        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 9    5d95e2535b96e82a26502a50       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T11:58:11.502Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 10   5d95e2585b96e82a26502a52       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T11:58:16.265Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 11   5d95e25b5b96e82a26502a54       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T11:58:19.669Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 12   5d95e25f5b96e82a26502a56       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T11:58:23.226Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 13   5d95e2695b96e82a26502a58       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T11:58:33.075Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 14   5d95e2705b96e82a26502a5a       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T11:58:40.680Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 15   5d95e2745b96e82a26502a5c       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T11:58:44.089Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 16   5d95e2775b96e82a26502a5e       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T11:58:47.524Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 17   5d95e27b5b96e82a26502a60       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T11:58:51.071Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 18   5d95e2845b96e82a26502a62       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T11:59:00.627Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 19   5d95e2885b96e82a26502a64       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T11:59:04.123Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 20   5d95e28b5b96e82a26502a66       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T11:59:07.595Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 21   5d95e28f5b96e82a26502a68       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T11:59:11.201Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 22   5d95e3495b96e82a26502a6b       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T12:02:17.647Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 23   5d95e34d5b96e82a26502a6d       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T12:02:21.098Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 24   5d95e3505b96e82a26502a6f       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T12:02:24.520Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 25   5d95e3545b96e82a26502a71       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T12:02:28.078Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 26   5d95e36d5b96e82a26502a73       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T12:02:53.877Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 27   5d95e3715b96e82a26502a75       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T12:02:57.267Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 28   5d95e3745b96e82a26502a77       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T12:03:00.994Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 29   5d95e3795b96e82a26502a79       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T12:03:05.237Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 30   5d95e3825b96e82a26502a7b       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T12:03:14.740Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 31   5d95e3865b96e82a26502a7d       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T12:03:18.187Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 32   5d95e3895b96e82a26502a7f       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T12:03:21.640Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 33   5d95e38d5b96e82a26502a81       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T12:03:25.662Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 34   5d95e3985b96e82a26502a84       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T12:03:36.719Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 35   5d95e39c5b96e82a26502a86       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T12:03:40.144Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 36   5d95e39f5b96e82a26502a88       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T12:03:43.562Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 37   5d95e3a35b96e82a26502a8a       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T12:03:47.146Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 38   5d95e3ac5b96e82a26502a8c       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T12:03:56.548Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 39   5d95e3b15b96e82a26502a8e       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T12:04:01.004Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 40   5d95e3b45b96e82a26502a90       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T12:04:04.406Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 41   5d95e3b85b96e82a26502a92       72029              318008             1000  onPlayerError(String errorMessage)   32      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-03T12:04:08.014Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 42   5d95ef555b96e82a26502a95       72029              318008             1000  onPlayerError(String errorMessage)   33      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T12:53:41.042Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: None of the available extractor...        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 43   5d95ef555b96e82a26502a97       72029              318008             1000  onPlayerError(String errorMessage)   33      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T12:53:41.843Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: None of the available extractor...        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 44   5d95ef565b96e82a26502a99       72029              318008             1000  onPlayerError(String errorMessage)   33      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T12:53:42.485Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: None of the available extractor...        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 45   5d95ef575b96e82a26502a9a       72029              318008             1000                           onError()   33      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T12:53:43.229Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                 ANDROID-STB :: Wecast Player error        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 46   5d95ef575b96e82a26502a9c       72029              318008             1000  onPlayerError(String errorMessage)   33      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T12:53:43.272Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: None of the available extractor...        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 47   5d95f5d15b96e82a26502ab0       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:21:21.978Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 48   5d95f5d35b96e82a26502ab2       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:21:23.466Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 49   5d95f5d45b96e82a26502ab4       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:21:24.221Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 50   5d95f5d55b96e82a26502ab6       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:21:25.234Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 51   5d95f5d65b96e82a26502ab8       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:21:26.252Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 52   5d95f5d75b96e82a26502aba       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:21:27.058Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 53   5d95f5d75b96e82a26502abb       66915              312812             1000                           onError()    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:21:27.833Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                 ANDROID-STB :: Wecast Player error        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 54   5d95f5d75b96e82a26502abd       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:21:27.875Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 55   5d95f6385b96e82a26502abf       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:23:04.512Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 56   5d95f6395b96e82a26502ac1       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:23:05.127Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 57   5d95f6395b96e82a26502ac3       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:23:05.896Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 58   5d95f63a5b96e82a26502ac5       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:23:06.770Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 59   5d95f63b5b96e82a26502ac7       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:23:07.410Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 60   5d95f63c5b96e82a26502ac9       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:23:08.147Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 61   5d95f63c5b96e82a26502aca       66915              312812             1000                           onError()    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:23:08.953Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                 ANDROID-STB :: Wecast Player error        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 62   5d95f63c5b96e82a26502acc       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:23:08.997Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 63   5d95f6515b96e82a26502acf       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:23:29.249Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 64   5d95f6525b96e82a26502ad1       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:23:30.255Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 65   5d95f6525b96e82a26502ad3       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:23:30.973Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 66   5d95f65b5b96e82a26502ad5       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:23:39.555Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: Unable to connect to https://fl...        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 67   5d95f6615b96e82a26502ad7       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:23:45.503Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: Unable to connect to https://fl...        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 68   5d95f6675b96e82a26502ad9       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:23:51.471Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: Unable to connect to https://fl...        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 69   5d95f6835b96e82a26502add       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:24:19.597Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 404        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 70   5d95f8065b96e82a26502ae3       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:30:46.714Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 71   5d95f8075b96e82a26502ae5       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:30:47.482Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 72   5d95f8085b96e82a26502ae7       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:30:48.225Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 73   5d95f8085b96e82a26502ae9       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:30:48.987Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 74   5d95f8095b96e82a26502aeb       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:30:49.567Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 75   5d95f80a5b96e82a26502aed       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:30:50.535Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 76   5d95f80b5b96e82a26502aee       66915              312812             1000                           onError()    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:30:51.192Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                 ANDROID-STB :: Wecast Player error        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 77   5d95f80b5b96e82a26502af0       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:30:51.234Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 78   5d95f8145b96e82a26502af3       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:31:00.906Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: Unable to connect to https://cd...        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 79   5d95f8175b96e82a26502af5       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:31:03.965Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: Unable to connect to https://cd...        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 80   5d95f81a5b96e82a26502af7       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:31:06.905Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: Unable to connect to https://cd...        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 81   5d95f81d5b96e82a26502af8       66915              312812             1000                           onError()    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:31:09.883Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                 ANDROID-STB :: Wecast Player error        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 82   5d95f81d5b96e82a26502afa       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:31:09.927Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: Unable to connect to https://cd...        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 83   5d95f8405b96e82a26502afe       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:31:44.594Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: Unable to connect to https://cd...        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 84   5d95f8435b96e82a26502b00       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:31:47.643Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: Unable to connect to https://cd...        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 85   5d95f8465b96e82a26502b02       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:31:50.670Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: Unable to connect to https://cd...        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 86   5d95f8495b96e82a26502b04       66915              312812             1000                           onError()    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:31:53.629Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                 ANDROID-STB :: Wecast Player error        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 87   5d95f8495b96e82a26502b06       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:31:53.712Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: Unable to connect to https://cd...        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 88   5d95fc1d5b96e82a26502b11       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:48:13.962Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833        ANDROID-STB :: Behind live window exception        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 89   5d95fd555b96e82a26502b17       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:53:25.123Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833        ANDROID-STB :: Behind live window exception        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 90   5d95fe9a5b96e82a26502b1a       66915              312812             1000  onPlayerError(String errorMessage)    1      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-03T13:58:50.306Z  NVIDIA SHIELD Android TV         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833        ANDROID-STB :: Behind live window exception        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0
# 91   5d9709de5b96e82a26502bd8       72029              318008             1000  onPlayerError(String errorMessage)   33      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-04T08:59:10.476Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 92   5d9709e15b96e82a26502bda       72029              318008             1000  onPlayerError(String errorMessage)   33      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-04T08:59:13.955Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 93   5d9709e55b96e82a26502bdc       72029              318008             1000  onPlayerError(String errorMessage)   33      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-04T08:59:17.365Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 94   5d9709e85b96e82a26502bde       72029              318008             1000  onPlayerError(String errorMessage)   33      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-04T08:59:20.960Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 95   5d9709f95b96e82a26502be0       72029              318008             1000  onPlayerError(String errorMessage)   33      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-04T08:59:37.325Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 96   5d9709fc5b96e82a26502be2       72029              318008             1000  onPlayerError(String errorMessage)   33      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-04T08:59:40.872Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 301        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# ...
# 126  5d970d6e5b96e82a26502c1d       72029              318008             1000                           onError()   33      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-04T09:14:22.193Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                 ANDROID-STB :: Wecast Player error        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 127  5d970d6e5b96e82a26502c1e       72029              318008             1000                           onError()   33      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-04T09:14:22.283Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                 ANDROID-STB :: Wecast Player error        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 128  5d970db55b96e82a26502c20       72029              318008             1000                           onError()   33      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-04T09:15:33.318Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                 ANDROID-STB :: Wecast Player error        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 129  5d970dbb5b96e82a26502c21       72029              318008             1000                           onError()   33      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-04T09:15:39.108Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                 ANDROID-STB :: Wecast Player error        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 130  5d970dbb5b96e82a26502c22       72029              318008             1000                           onError()   33      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-04T09:15:39.175Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                 ANDROID-STB :: Wecast Player error        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 131  5d9de7e8fc76b038d019575f       68871              314810             1000  onPlayerError(String errorMessage)   33      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-09T14:00:08.432Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 132  5d9de7eafc76b038d0195761       68871              314810             1000  onPlayerError(String errorMessage)   33      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-09T14:00:10.327Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 133  5d9de7ebfc76b038d0195763       68871              314810             1000  onPlayerError(String errorMessage)   33      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-09T14:00:11.514Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 134  5d9de7ecfc76b038d0195764       68871              314810             1000                           onError()   33      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-09T14:00:12.669Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                 ANDROID-STB :: Wecast Player error        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 135  5d9de7ecfc76b038d0195766       68871              314810             1000  onPlayerError(String errorMessage)   33      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-09T14:00:12.793Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                                ANDROID-STB :: null        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 136  5d9f1efcfc76b038d0195778       68754              314689             1000                    onTokenExpired()   20      NaN  Sarajevo        wetek.com.wecast.ui.loading.LoadingFragment  Bosnia and Herzegovina           BA  2019-10-10T12:07:24.125Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                   ANDROID-STB :: Token has expired        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 137  5d9f1efcfc76b038d0195779       68754              314689             1000                    onTokenExpired()   20      NaN  Sarajevo        wetek.com.wecast.ui.loading.LoadingFragment  Bosnia and Herzegovina           BA  2019-10-10T12:07:24.169Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                   ANDROID-STB :: Token has expired        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 138  5d9f1efcfc76b038d019577a       68754              314689             1000                    onTokenExpired()   20      NaN  Sarajevo        wetek.com.wecast.ui.loading.LoadingFragment  Bosnia and Herzegovina           BA  2019-10-10T12:07:24.214Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                   ANDROID-STB :: Token has expired        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 139  5d9f1efcfc76b038d019577b       68754              314689             1000                    onTokenExpired()   20      NaN  Sarajevo        wetek.com.wecast.ui.loading.LoadingFragment  Bosnia and Herzegovina           BA  2019-10-10T12:07:24.215Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                   ANDROID-STB :: Token has expired        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 140  5d9f1efefc76b038d019577c       68754              314689             1000                           onError()   20      NaN  Sarajevo        wetek.com.wecast.ui.loading.LoadingFragment  Bosnia and Herzegovina           BA  2019-10-10T12:07:26.760Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: Attempt to invoke virtual metho...        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 141  5d9f1f74fc76b038d019577d       68754              314689             1000                    onTokenExpired()   20      NaN  Sarajevo        wetek.com.wecast.ui.loading.LoadingFragment  Bosnia and Herzegovina           BA  2019-10-10T12:09:24.845Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                   ANDROID-STB :: Token has expired        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 142  5d9f1f74fc76b038d019577e       68754              314689             1000                    onTokenExpired()   20      NaN  Sarajevo        wetek.com.wecast.ui.loading.LoadingFragment  Bosnia and Herzegovina           BA  2019-10-10T12:09:24.892Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                   ANDROID-STB :: Token has expired        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 143  5d9f2631fc76b038d0195780       68754              314689             1000                           onError()   20      NaN  Sarajevo        wetek.com.wecast.ui.loading.LoadingFragment  Bosnia and Herzegovina           BA  2019-10-10T12:38:09.869Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: Attempt to invoke virtual metho...        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 144  5d9f2e8bfc76b038d0195781       68754              314689             1000                    onTokenExpired()   20      NaN  Sarajevo        wetek.com.wecast.ui.loading.LoadingFragment  Bosnia and Herzegovina           BA  2019-10-10T13:13:47.980Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                   ANDROID-STB :: Token has expired        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 145  5d9f2e8cfc76b038d0195782       68754              314689             1000                    onTokenExpired()   20      NaN  Sarajevo        wetek.com.wecast.ui.loading.LoadingFragment  Bosnia and Herzegovina           BA  2019-10-10T13:13:48.213Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                   ANDROID-STB :: Token has expired        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 146  5d9f2e8dfc76b038d0195783       68754              314689             1000                           onError()   20      NaN  Sarajevo        wetek.com.wecast.ui.loading.LoadingFragment  Bosnia and Herzegovina           BA  2019-10-10T13:13:49.201Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: Attempt to invoke virtual metho...        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 147  5d9f2ec0fc76b038d0195784       68754              314689             1000                    onTokenExpired()   20      NaN  Sarajevo        wetek.com.wecast.ui.loading.LoadingFragment  Bosnia and Herzegovina           BA  2019-10-10T13:14:40.063Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                   ANDROID-STB :: Token has expired        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 148  5d9f2ec1fc76b038d0195785       68754              314689             1000                           onError()   20      NaN  Sarajevo        wetek.com.wecast.ui.loading.LoadingFragment  Bosnia and Herzegovina           BA  2019-10-10T13:14:41.019Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: Attempt to invoke virtual metho...        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 149  5d9f2f2efc76b038d0195786       68754              314689             1000                           onError()   20      NaN  Sarajevo        wetek.com.wecast.ui.loading.LoadingFragment  Bosnia and Herzegovina           BA  2019-10-10T13:16:30.110Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: Attempt to invoke virtual metho...        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 150  5d9f36c8fc76b038d0195787       68754              314689             1000                    onTokenExpired()   20      NaN  Sarajevo        wetek.com.wecast.ui.loading.LoadingFragment  Bosnia and Herzegovina           BA  2019-10-10T13:48:56.161Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                   ANDROID-STB :: Token has expired        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 151  5d9f36c9fc76b038d0195788       68754              314689             1000                           onError()   20      NaN  Sarajevo        wetek.com.wecast.ui.loading.LoadingFragment  Bosnia and Herzegovina           BA  2019-10-10T13:48:57.284Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: Attempt to invoke virtual metho...        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 152  5d9f3703fc76b038d0195789       68754              314689             1000                    onTokenExpired()   20      NaN  Sarajevo        wetek.com.wecast.ui.loading.LoadingFragment  Bosnia and Herzegovina           BA  2019-10-10T13:49:55.689Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                   ANDROID-STB :: Token has expired        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 153  5d9f3706fc76b038d019578a       68754              314689             1000                           onError()   20      NaN  Sarajevo        wetek.com.wecast.ui.loading.LoadingFragment  Bosnia and Herzegovina           BA  2019-10-10T13:49:58.380Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833  ANDROID-STB :: Attempt to invoke virtual metho...        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 154  5d9f3a2dfc76b038d019578b       68754              314689             1000                    onTokenExpired()   20      NaN  Sarajevo        wetek.com.wecast.ui.loading.LoadingFragment  Bosnia and Herzegovina           BA  2019-10-10T14:03:25.802Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                   ANDROID-STB :: Token has expired        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 155  5d9f3a2efc76b038d019578c       68754              314689             1000                    onTokenExpired()   20      NaN  Sarajevo        wetek.com.wecast.ui.loading.LoadingFragment  Bosnia and Herzegovina           BA  2019-10-10T14:03:26.128Z                 WeTek Air         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                   ANDROID-STB :: Token has expired        [  ]   m               16          1  Europe/Sarajevo  okhttp/4.2.0
# 156  5da420d0fc76b038d01957f4       72029              318008             1000  onPlayerError(String errorMessage)   33      NaN  Sarajevo  wetek.com.wecast.ui.linearHome.LinearHomeActivity  Bosnia and Herzegovina           BA  2019-10-14T07:16:32.644Z                 WeTek Hub         stb       [  ]  84.41.117.102                   Softnet    43.85   18.3833                  ANDROID-STB :: Response code: 404        [  ]   m               85          3  Europe/Sarajevo  okhttp/4.2.0
# 157  5da83225fc76b038d0195a41       66915              312812               50  onPlayerError(String errorMessage)    1      NaN  Sarajevo    wetek.com.wecast.ui.vodPlayer.VodPlayerActivity  Bosnia and Herzegovina           BA  2019-10-17T09:19:33.220Z  NVIDIA SHIELD Android TV         stb       [  ]  31.185.126.36  Telemach d.o.o. Sarajevo    43.85   18.3833                  ANDROID-STB :: Response code: 404        [  ]   f               16          1  Europe/Sarajevo  okhttp/4.2.0

# %% [markdown]
# Data exploratory analysis

# %%
incidents.nunique()
# Out:
# _id                   158
# account_id              4
# account_profile_id      4
# accuracy_radius         2
# action                  3
# age                     4
# app_ver                 0
# city                    1
# controller              3
# country                 1
# country_code            1
# created               158
# device_model            3
# device_type             1
# get_params              1
# ip_address              2
# isp                     2
# loc.lat                 1
# loc.long                1
# message                10
# post_params             1
# sex                     2
# subscription_id         2
# tenant_id               2
# time_zone               1
# user_agent              1
# dtype: int64

# %%
incidents['action'].value_counts()
# Out:
# onPlayerError(String errorMessage)    113
# onError()                              32
# onTokenExpired()                       13
# Name: action, dtype: int64

# %%
incidents['message'].value_counts()
# Out:
# ANDROID-STB :: Response code: 301                                                                                                                                                                                                                                              56
# ANDROID-STB :: null                                                                                                                                                                                                                                                            28
# ANDROID-STB :: Wecast Player error                                                                                                                                                                                                                                             25
# ANDROID-STB :: Token has expired                                                                                                                                                                                                                                               13
# ANDROID-STB :: None of the available extractors (MatroskaExtractor, FragmentedMp4Extractor, Mp4Extractor, Mp3Extractor, AdtsExtractor, Ac3Extractor, TsExtractor, FlvExtractor, OggExtractor, PsExtractor, WavExtractor, AmrExtractor, Ac4Extractor) could read the stream.    12
# ANDROID-STB :: Unable to connect to https://cdn.playtime.pt/vod/WeCast1_live_task_node_config_21/1/playlist.m3u8                                                                                                                                                                8
# ANDROID-STB :: Attempt to invoke virtual method 'java.util.List wetek.com.wecastsdk.model.PagedData.getItems()' on a null object reference                                                                                                                                      7
# ANDROID-STB :: Unable to connect to https://flussonic-dev-02.fibernet-tv.com/AMC-1757/index.m3u8                                                                                                                                                                                3
# ANDROID-STB :: Response code: 404                                                                                                                                                                                                                                               3
# ANDROID-STB :: Behind live window exception                                                                                                                                                                                                                                     3
# Name: message, dtype: int64
