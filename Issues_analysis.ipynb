# %% [markdown]
# Import standard packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Setting display option

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# Read data

# %%
issues = pd.read_csv("play_issues.csv")
# Out:
# /home/fuad/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
issues.head(100)
# Out:
#                          _id  account_id  account_profile_id  accuracy_radius   age app_ver  b_duration  buffer          city                 country country_code  crash                   created                                       device_model     device_type       ip_address         isp  loc.lat  loc.long  model_id  model_type    record_model sex  subscription_id        time_zone    user_agent
# 0   5d955ad258e14dd2e8680a73       66921              312819              NaN   0.0    2.22        15.0       1      Sarajevo  Bosnia and Herzegovina           BA      0  2019-10-03T02:20:02.000Z                                                NaN             NaN  188.127.102.231         NaN  43.8500   18.3833       486           1  SingleEventVod   m                1  Europe/Sarajevo  Dalvik/2.1.0
# ...

# %% [markdown]
# Data exploratory analysis

# %%
issues.nunique()
# Out:
# _id                   605565
# account_id               300
# account_profile_id      1071
# accuracy_radius          220
# age                       57
# app_ver                   12
# b_duration                42
# buffer                     2
# city                       7
# country                    2
# country_code               2
# crash                      2
# created                12723
# device_model              26
# device_type                8
# ip_address              1060
# isp                       15
# loc.lat                    4
# loc.long                   4
# model_id                 647
# model_type                 2
# record_model               2
# sex                        2
# subscription_id           24
# time_zone                  2
# user_agent                 3
# dtype: int64

# %%
issues['buffer'].value_counts()
# Out:
# 0    303503
# 1    302062
# Name: buffer, dtype: int64

# %%
grouped1 = issues.groupby('account_profile_id').mean() #group by users 
                                                    #and saving the mean value for each type

# %%
grouped1['b_duration'][-grouped1['b_duration'].isna()].mean() #calculate the buffer duration in seconds by user
# Out:
# 24.987829663852064

# %%
grouped2 = issues.groupby('model_id').mean()#group by channels
                                                    #and saving the mean value for each type

# %%
grouped2['b_duration'].mean() #calculate the buffer duration in seconds by channel
# Out:
# 25.048247201106033

# %%
sum(issues['crash'])*100/issues['crash'].size    #sums all crashes that have 1 if crashed and 0 value if not
                                                 #and divides with the whole collumn size
# Out:
# 50.24596864085606
